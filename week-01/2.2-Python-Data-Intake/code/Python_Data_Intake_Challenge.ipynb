# %%
import csv
print 'Opening File. Data: '
print ''
# use your own file path or simply yob1880.txt
file = '/Users/jam3jam/dsi/pydata-book/ch02/names/yob1880.txt'
with open(file, 'rU') as f:
    reader = csv.reader(f)
    for row in reader:
        print row
# Out:
# Opening File. Data:
#
# ['Mary', 'F', '7065']
# ['Anna', 'F', '2604']
# ['Emma', 'F', '2003']
# ['Elizabeth', 'F', '1939']
# ['Minnie', 'F', '1746']
# ['Margaret', 'F', '1578']
# ['Ida', 'F', '1472']
# ['Alice', 'F', '1414']
# ['Bertha', 'F', '1320']
# ['Sarah', 'F', '1288']
# ['Annie', 'F', '1258']
# ['Clara', 'F', '1226']
# ['Ella', 'F', '1156']
# ['Florence', 'F', '1063']
# ['Cora', 'F', '1045']
# ['Martha', 'F', '1040']
# ['Laura', 'F', '1012']
# ['Nellie', 'F', '995']
# ['Grace', 'F', '982']
# ['Carrie', 'F', '949']
# ['Maude', 'F', '858']
# ['Mabel', 'F', '808']
# ['Bessie', 'F', '794']
# ['Jennie', 'F', '793']
# ['Gertrude', 'F', '787']
# ['Julia', 'F', '783']
# ['Hattie', 'F', '769']
# ['Edith', 'F', '768']
# ['Mattie', 'F', '704']
# ['Rose', 'F', '700']
# ['Catherine', 'F', '688']
# ['Lillian', 'F', '672']
# ['Ada', 'F', '652']
# ['Lillie', 'F', '647']
# ['Helen', 'F', '636']
# ['Jessie', 'F', '635']
# ['Louise', 'F', '635']
# ['Ethel', 'F', '633']
# ['Lula', 'F', '621']
# ...

# %%
# Calculate number of total males and females - submitted by John Hou

import csv
female_cnt=0
male_cnt=0
with open(file, 'rU') as f:
   reader = csv.reader(f)
   for row in reader:
       if row[1] == 'F':
           female_cnt += int(row[2])
       else:
           male_cnt += int(row[2])
           
print(female_cnt)
print(male_cnt)
# Out:
# 90993
# 110493

# %%
# Calculate number of total males and females - submitted by Kari Benson

import csv
with open(file, 'r') as f:
   reader = csv.reader(f)
   female_count = 0
   male_count = 0
   for row in reader:
       if row[1] == 'F':
           female_count += int(row[2])
       else:
           male_count += int(row[2])
   print "Number of females in 1880: ", female_count
   print ''
   print "Number of males in 1880: ", male_count
# Out:
# Number of females in 1880:  90993
#
# Number of males in 1880:  110493

# %%
import pandas as pd
# %matplotlib inline

names1880 = pd.read_csv(file, names=['name', 'sex', 'births'])

# import matplotlib
# import numpy as np
# import matplotlib.pyplot as plt
import seaborn as sb
names1880.births.hist()

# %%
names1880.groupby('sex').births.sum()
# Out:
# sex
# F     90993
# M    110493
# Name: births, dtype: int64
