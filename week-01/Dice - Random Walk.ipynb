# %%
import numpy as np
np.random.seed(123)

random_walk = [0]

for x in range(100):
    step = random_walk[-1]
    
    dice = np.random.randint(1,7)
    
    if dice <= 2:
        step = max(0, step -1)
    elif dice <= 5:
        step += 1
    else:
        step = np.random.randint(1,7)
    
    random_walk.append(step)
  
print(random_walk)
# Out:
# [0, 3, 4, 5, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1, 0, 0, 1, 5, 4, 3, 4, 3, 4, 5, 6, 7, 8, 7, 1, 0, 1, 2, 3, 4, 3, 4, 5, 4, 5, 4, 5, 6, 1, 2, 3, 4, 5, 3, 4, 5, 6, 5, 6, 4, 5, 4, 5, 6, 5, 6, 7, 2, 3, 4, 3, 2, 3, 4, 3, 2, 3, 4, 2, 1, 0, 1, 0, 1, 2, 3, 2, 1, 2, 3, 4, 5, 6, 5, 4, 5, 4, 5, 6, 5, 3, 4, 5, 6, 5, 1, 1]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.plot(random_walk)
plt.show()
