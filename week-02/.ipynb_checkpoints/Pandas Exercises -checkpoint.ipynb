# %%
import pandas as pd

# %%
pwd
# Out:
# u'/Users/toddmoffett1/DSI/dsi_workspace/curriculum/week-02'

# %%
df = pd.read_csv('StarWars.csv')

# %%
df
# Out:
#       RespondentID  \
# 0              NaN
# 1     3.292880e+09
# 2     3.292880e+09
# 3     3.292765e+09
# 4     3.292763e+09
# 5     3.292731e+09
# 6     3.292719e+09
# 7     3.292685e+09
# 8     3.292664e+09
# 9     3.292654e+09
# 10    3.292640e+09
# 11    3.292638e+09
# 12    3.292635e+09
# 13    3.292609e+09
# 14    3.292597e+09
# 15    3.292587e+09
# 16    3.292583e+09
# 17    3.292581e+09
# 18    3.292573e+09
# 19    3.292565e+09
# 20    3.292562e+09
# 21    3.292522e+09
# 22    3.292521e+09
# 23    3.292512e+09
# 24    3.292483e+09
# 25    3.292465e+09
# 26    3.292448e+09
# 27    3.292420e+09
# 28    3.292384e+09
# 29    3.292380e+09
# ...            ...
# 1157  3.288426e+09
# 1158  3.288423e+09
# 1159  3.288423e+09
# 1160  3.288422e+09
# 1161  3.288421e+09
# 1162  3.288418e+09
# 1163  3.288418e+09
# 1164  3.288417e+09
# 1165  3.288415e+09
# 1166  3.288414e+09
# 1167  3.288413e+09
# 1168  3.288410e+09
# 1169  3.288410e+09
# 1170  3.288409e+09
# 1171  3.288403e+09
# ...

# %%
list(df.columns.values).index('Age')
# Out:
# 34

# %%
df.columns.values
# Out:
# array(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        'Which of the following Star Wars films have you seen? Please select all that apply.',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8',
#        'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14',
#        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Which character shot first?',
# ...

# %%
list(df.columns.values).index('Age') #python list function
# Out:
# 34

# %%
import numpy as np

# %%
int(np.where(df.columns == 'Age')[0])
# Out:
# 34

# %%
np.where(df.columns =='Gender')[0][0]
# Out:
# 33

# %%
df.columns.get_loc('Age')
# Out:
# 34

# %%
df_file = '../week-01/2.2-Python-Data-Intake/yob1880.txt'

# %%
yob = pd.read_csv(df_file, names=['Name', 'Gender', 'Count'])

# %%
yob.head()
# Out:
#         Name Gender  Count
# 0       Mary      F   7065
# 1       Anna      F   2604
# 2       Emma      F   2003
# 3  Elizabeth      F   1939
# 4     Minnie      F   1746

# %%
females = yob['Gender'] == 'F'

# %%
print 'Females :', yob[yob['Gender'] == 'F']['Count'].sum()
print 'Males :', yob
# Out:
# Females : 90993

# %%
yob.groupby(by=['Gender'])['Count'].sum()
# Out:
# Gender
# F     90993
# M    110493
# Name: Count, dtype: int64

# %%
female_count = [yob['female total'] = sum(yob['7065']) and [yob['F'] ]
# Out:
#   File "<ipython-input-58-bb977fec3144>", line 1
#     female_count = [yob['female total'] = sum(yob['7065']) and [yob['F'] ]
#                                         ^
# SyntaxError: invalid syntax

# %%
if females:
    female_count = [yob['female total'] = sum(yob['Count'])
# Out:
#   File "<ipython-input-83-919fb457ae03>", line 2
#     female_count = [[yob['female total'] = sum(yob['Count'])]
#                                          ^
# SyntaxError: invalid syntax
