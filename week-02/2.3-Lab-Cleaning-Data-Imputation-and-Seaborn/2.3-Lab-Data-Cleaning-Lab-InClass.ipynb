# %% [markdown]
# ---
# title: Data Cleaning Lab + Mini-Lesson on Visualization
# type: lab
# duration: "1:5"
# creator:
#     name: Joshua Cook
#     city: Santa Monica
# ---

# %% [markdown]
# # Basic Visualizations with Seaborn

# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

iris_data_location = '../data/iris.csv'
iris_data_dataframe = pd.read_csv(iris_data_location,
                                  index_col=False,
                                  header=0,
                                  names=['sepal_length', 
                                         'sepal_width',
                                         'petal_length',
                                         'petal_width',
                                         'class'])

# %%
iris_data_dataframe.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa

# %% [markdown]
# ## Using `seaborn`
#
# http://seaborn.pydata.org/api.html

# %% [markdown]
# ### `sns.pairplot`
#
# Plots pairwise relationships in a dataset.
#
# - draws scatterplots for joint relationships
# - draws histograms for univariate relationships

# %%
sns.pairplot(iris_data_dataframe)

# %% [markdown]
# ### `sns.countplot`
#
# Show the counts of observations in each categorical bin using bars.
#
# A count plot can be thought of as a histogram across a categorical, instead of quantitative, variable.

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='class',
               data=iris_data_dataframe)

# %%
sns.countplot(x='petal_length',
               data=iris_data_dataframe,
               palette='hot')

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='petal_length',
               data=iris_data_dataframe)

# %% [markdown]
# ### `sns.stripplot`
#
# Draw a scatterplot where one variable is categorical.
#
# A strip plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.

# %%
sns.stripplot(x='class',
               y='sepal_length',
               data=iris_data_dataframe)

# %% [markdown]
# ### `sns.swarmplot`
#
# Draw a categorical scatterplot with non-overlapping points.
#
# This function is similar to `stripplot()`, but the points are adjusted (only along the categorical axis) so that they don’t overlap.

# %%
sns.violinplot(x='class',
               y='sepal_length',
               data=iris_data_dataframe)

# %%
sns.swarmplot(x='class',
               y='sepal_length',
               data=iris_data_dataframe)

# %% [markdown]
# ### `sns.boxplot`
#
# Draw a box plot to show distributions with respect to categories.
#
# A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable.
#
# The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.
#
# https://en.wikipedia.org/wiki/Box_plot

# %%
sns.boxplot(x='class',
               y='sepal_length',
               data=iris_data_dataframe)

# %% [markdown]
# ### `sns.barplot`
#
# Draw a box plot to show distributions with respect to categories.
#
# A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable.
#
# The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.
#
# https://en.wikipedia.org/wiki/Box_plot

# %%
sns.barplot(x='class',
               y='sepal_length',
               data=iris_data_dataframe)

# %% [markdown]
# ### Subplots

# %%
fig = plt.figure(figsize=(20,6))
fig.add_subplot(121)
sns.violinplot(x='class', 
               y='sepal_length', 
               data=iris_data_dataframe)
fig.add_subplot(122)
sns.violinplot(x='class', 
               y='sepal_width', 
               data=iris_data_dataframe)

# %%
fig = plt.figure(figsize=(20,12))
for i, param in enumerate(['sepal_length', 
                           'sepal_width',
                           'petal_length',
                           'petal_width']):
    
    fig.add_subplot(221+i)
    plt.title('class v.' + param)
    sns.swarmplot(x='class',
                   y=param,
                   data=iris_data_dataframe)

# %% [markdown]
# # Lab: Data Cleaning

# %%
lusitania_data_location = '../../../projects/project-02/assets/lusitania.csv'
titanic_data_location = '../../../projects/project-02/assets/titanic.csv'
titnc_df = pd.read_csv(titanic_data_location)
lusit_df = pd.read_csv(lusitania_data_location)

# %%
titnc_age_nullness = pd.isnull(titnc_df['age'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15       True
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1279    False
# 1280    False
# 1281    False
# 1282     True
# 1283     True
# 1284     True
# 1285    False
# 1286    False
# 1287    False
# 1288    False
# 1289    False
# 1290    False
# 1291     True
# 1292     True
# 1293     True
# 1294    False
# 1295    False
# 1296    False
# 1297     True
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302     True
# 1303     True
# 1304    False
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: age, dtype: bool

# %%
titnc_age_nullness = pd.isnull(titnc_df['age'])
titnc_df[titnc_age_nullness]
# Out:
#       pclass  survived                                               name  \
# 15         1         0                                Baumann, Mr. John D
# 37         1         1      Bradley, Mr. George ("George Arthur Brayton")
# 40         1         0                          Brewe, Dr. Arthur Jackson
# 46         1         0                              Cairns, Mr. Alexander
# 59         1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 69         1         1             Chibnall, Mrs. (Edith Martha Bowerman)
# 70         1         0              Chisholm, Mr. Roderick Robert Crispin
# 74         1         0                        Clifford, Mr. George Quincy
# 80         1         0                          Crafton, Mr. John Bertram
# 106        1         0                                 Farthing, Mr. John
# 107        1         1               Flegenheim, Mrs. Alfred (Antoinette)
# 108        1         1                            Fleming, Miss. Margaret
# ...

# %% [markdown]
# ## What I couldn't do earlier

# %%
lusit_df.Age.unique()
# Out:
# array(['38', '37', '30', '25', '27', '48', nan, '24', '19 ?', '57', '50',
#        '56', '41', '19', '33', '29', '18', '20', '21', '26', '17', '58',
#        '47', '54', '35', '43', '59', '53', '44', '51', '40', '49', '42',
#        '32', '31', '34', '22', '45', '36', '29 ?', '52', '23', '60', '28',
#        '16', '46', '15', '39', '63 ?', '55', '64', '53 ?', '09-months',
#        '6', '9', '14', '10', '12', '?', '62', '5', '8', '65', '68', '76',
#        '61', '63', '03-months', '1.5', '2.5', '18-months', '3', '2',
#        '25 ?', '08-months', '4', '15-months', '14-months', 'Infant',
#        '3-6-months ?', '51 or 47', '45 or 51', '22 (?)', '17-months',
#        '13-months', '02-months', '49 ?', '05-months', '11', '59 (64?)',
#        '63 (51?)', '37 (39?)', '32 (22?)', '31 (32?)', '24 (23?)', '27?',
#        '7', '42?', '31 ?', '10-months', '38 (?)', '70', '62 (?)',
#        '06-months', '13', '2_', '11-months', '30 ?', '34?', '1',
# ...

# %%
def drop_word_months(age):
    try:
        return str(float(age.lower().replace('-months',''))/12.)
    except ValueError:
        return age

# %%
drop_word_months = lambda x: float(x.lower().replace('-months',''))/12.
bad_age_1 = '63-Months'
bad_age_2 = '15-months'
drop_word_months(bad_age_1), drop_word_months(bad_age_2)
# Out:
# (5.25, 1.25)

# %%
lusit_not_null = pd.notnull(lusit_df['Age'])
type(lusit_not_null), lusit_not_null.shape, lusit_not_null[:5]
# Out:
# (pandas.core.series.Series, (1961,), 0    True
#  1    True
#  2    True
#  3    True
#  4    True
#  Name: Age, dtype: bool)

# %%
lusit_df_age_not_null = lusit_df[lusit_not_null]
lusit_df_age_not_null.head(3)
# Out:
#   Family name Title Personal name   Fate Age Department/Class Passenger/Crew  \
# 0     CAMERON   Mr.    Charles W.   Lost  38             Band           Crew
# 1  CARR-JONES   Mr.            E.   Lost  37             Band           Crew
# 2   DRAKEFORD   Mr.        Edward  Saved  30             Band           Crew
#
#   Citizenship Position Status  ...  Country Lifeboat Rescue Vessel Body No.  \
# 0     British      NaN    NaN  ...      NaN      NaN           NaN      NaN
# 1     British      NaN    NaN  ...      NaN      NaN           NaN      NaN
# 2     British   Violin    NaN  ...      NaN      NaN           NaN      NaN
#
#   Ticket No. Cabin No. Traveling Companions and other notes Value Adult/Minor  \
# 0        NaN       NaN                                  NaN     1       Adult
# 1        NaN       NaN                                  NaN     1       Adult
# 2        NaN       NaN                                  NaN     1       Adult
#
#     Sex
# 0  Male
# 1  Male
# ...

# %%
months_in_age = lusit_df_age_not_null.Age.str.contains('months')
type(months_in_age), months_in_age.shape, months_in_age[:5]
# Out:
# (pandas.core.series.Series, (1308,), 0    False
#  1    False
#  2    False
#  3    False
#  4    False
#  Name: Age, dtype: bool)

# %%
lusit_df_months_in_age = lusit_df_age_not_null[months_in_age]
lusit_df_months_in_age.head(1)
# Out:
#     Family name   Title  Personal name  Fate        Age Department/Class  \
# 448    CROMPTON  Master  Peter Romilly  Lost  09-months           Saloon
#
#     Passenger/Crew  Citizenship Position  Status  ...  Country Lifeboat  \
# 448      Passenger  British/USA      NaN  Single  ...      USA      NaN
#
#     Rescue Vessel Body No. Ticket No. Cabin No.  \
# 448           NaN      214      46081      D 60
#
#                   Traveling Companions and other notes Value Adult/Minor   Sex
# 448  Paul Crompton (father), Gladys Crompton (mothe...     1      Infant  Male
#
# [1 rows x 23 columns]

# %%
pd.apply()

# %%
lusit_df.ix[448]
# Out:
# Family name                                                                      CROMPTON
# Title                                                                              Master
# Personal name                                                               Peter Romilly
# Fate                                                                                 Lost
# Age                                                                             09-months
# Department/Class                                                                   Saloon
# Passenger/Crew                                                                  Passenger
# Citizenship                                                                   British/USA
# Position                                                                              NaN
# Status                                                                             Single
# ...

# %%
lusit_df_months_in_age.loc['Age'] = lusit_df_months_in_age.Age.apply(drop_word_months)
# Out:
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/generic.py:2773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
lusit_df_months_in_age.ix[448]
# Out:
# Family name                                                                      CROMPTON
# Title                                                                              Master
# Personal name                                                               Peter Romilly
# Fate                                                                                 Lost
# Age                                                                                  0.75
# Department/Class                                                                   Saloon
# Passenger/Crew                                                                  Passenger
# Citizenship                                                                   British/USA
# Position                                                                              NaN
# Status                                                                             Single
# ...

# %%
lusit_df.head(50)
# Out:
#    Family name Title                      Personal name   Fate   Age  \
# 0      CAMERON   Mr.                         Charles W.   Lost    38
# 1   CARR-JONES   Mr.                                 E.   Lost    37
# 2    DRAKEFORD   Mr.                             Edward  Saved    30
# 3      HAWKINS   Mr.                             Handel  Saved    25
# 4    HEMINGWAY   Mr.                       John William  Saved    27
# 5     ANDERSON   Mr.                       James Clarke   Lost    48
# 6     ANDERSON   Mr.                               John   Lost   NaN
# 7       BATTLE   Mr.                              James  Saved   NaN
# 8       BESTIC   Mr.                      Albert Arthur  Saved    24
# 9       BOWDEN   Mr.                            Joseph   Saved  19 ?
# 10       BROWN   Mr.                 John Manson George   Lost    57
# 11      CANNON   Mr.                       Robert Henry   Lost    50
# 12     CLINTON   Mr.                             George  Saved   NaN
# ...

# %%
titnc_age_nullness = pd.isnull(titnc_df['age'])
titnc_df[titnc_age_nullness]
# Out:
#       pclass  survived                                               name  \
# 15         1         0                                Baumann, Mr. John D
# 37         1         1      Bradley, Mr. George ("George Arthur Brayton")
# 40         1         0                          Brewe, Dr. Arthur Jackson
# 46         1         0                              Cairns, Mr. Alexander
# 59         1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 69         1         1             Chibnall, Mrs. (Edith Martha Bowerman)
# 70         1         0              Chisholm, Mr. Roderick Robert Crispin
# 74         1         0                        Clifford, Mr. George Quincy
# 80         1         0                          Crafton, Mr. John Bertram
# 106        1         0                                 Farthing, Mr. John
# 107        1         1               Flegenheim, Mrs. Alfred (Antoinette)
# 108        1         1                            Fleming, Miss. Margaret
# ...

# %%
# Load It

# %%
# Summarize It (mean, median, mode, variance, std, range)

# %%
# Clean It

# %%
# Does cleaning it change the summary information?
