# %% [markdown]
# ---
# title: Data Cleaning Lab + Mini-Lesson on Visualization
# type: lab
# duration: "1:5"
# creator:
#     name: Joshua Cook
#     city: Santa Monica
# ---

# %% [markdown]
# # Basic Visualizations with Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
iris_data_location = '../data/iris.csv'
iris_data_dataframe = pd.read_csv(iris_data_location,
                                  index_col=False,
                                  header=0,
                                  names=['sepal_length', 
                                         'sepal_width',
                                         'petal_length',
                                         'petal_width',
                                         'class'])

# %%
iris_data_dataframe.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Using `seaborn`
#
# http://seaborn.pydata.org/api.html

# %% [markdown]
# ### `sns.pairplot`
#
# Plots pairwise relationships in a dataset.
#
# - draws scatterplots for joint relationships
# - draws histograms for univariate relationships

# %%
sns.pairplot(iris_data_dataframe)

# %% [markdown]
# ### `sns.countplot`
#
# Show the counts of observations in each categorical bin using bars.
#
# A count plot can be thought of as a histogram across a categorical, instead of quantitative, variable.

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='class',
               data=iris_data_dataframe)

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='petal_length',
               data=iris_data_dataframe)

# %% [markdown]
# ### `sns.stripplot`
#
# Draw a scatterplot where one variable is categorical.
#
# A strip plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.

# %%
sns.stripplot(x='class',
               y='sepal_length',
               data=iris_data_dataframe, )

# %% [markdown]
# ### `sns.swarmplot`
#
# Draw a categorical scatterplot with non-overlapping points.
#
# This function is similar to `stripplot()`, but the points are adjusted (only along the categorical axis) so that they don’t overlap.

# %%
sns.violinplot(x='class',
               y='sepal_length',
               data=iris_data_dataframe)

# %%
sns.swarmplot(x='class',
               y='sepal_length',
               data=iris_data_dataframe)

# %% [markdown]
# ### `sns.boxplot`
#
# Draw a box plot to show distributions with respect to categories.
#
# A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable.
#
# The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.
#
# https://en.wikipedia.org/wiki/Box_plot

# %%
sns.boxplot(x='class',
               y='sepal_length',
               data=iris_data_dataframe)

# %% [markdown]
# ### `sns.barplot`
#
# Draw a box plot to show distributions with respect to categories.
#
# A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable.
#
# The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.
#
# https://en.wikipedia.org/wiki/Box_plot

# %%
sns.barplot(x='class',
               y='sepal_length',
               data=iris_data_dataframe)

# %% [markdown]
# ### Subplots

# %%
fig = plt.figure(figsize=(20,6))
fig.add_subplot(121)
sns.violinplot(x='class', 
               y='sepal_length', 
               data=iris_data_dataframe)
fig.add_subplot(122)
sns.violinplot(x='class', 
               y='sepal_width', 
               data=iris_data_dataframe)

# %%
fig = plt.figure(figsize=(20,12))
for i, param in enumerate(['sepal_length', 
                           'sepal_width',
                           'petal_length',
                           'petal_width']):
    
    fig.add_subplot(221+i)
    plt.title('class v.' + param)
    sns.swarmplot(x='class',
                   y=param,
                   data=iris_data_dataframe)

# %% [markdown]
# # Lab: Data Cleaning

# %%
titanic_data_location = '/Users/toddmoffett1/DSI/dsi_workspace/project-2/assets/titanic.csv'
lusitania_data_location = '/Users/toddmoffett1/DSI/dsi_workspace/project-2/assets/lusitania.csv'

# %%
# Load It
titanic = pd.read_csv(titanic_data_location)
lusitania = pd.read_csv(lusitania_data_location)
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
lusitania_age = lusitania.Age
lusitania_age.to_csv('lusitania_ages.csv')

# %%
lusitania.head()
# Out:
#   Family name Title Personal name   Fate Age Department/Class Passenger/Crew  \
# 0     CAMERON   Mr.    Charles W.   Lost  38             Band           Crew
# 1  CARR-JONES   Mr.            E.   Lost  37             Band           Crew
# 2   DRAKEFORD   Mr.        Edward  Saved  30             Band           Crew
# 3     HAWKINS   Mr.        Handel  Saved  25             Band           Crew
# 4   HEMINGWAY   Mr.  John William  Saved  27             Band           Crew
#
#   Citizenship     Position Status  ...  Country Lifeboat Rescue Vessel  \
# 0     British          NaN    NaN  ...      NaN      NaN           NaN
# 1     British          NaN    NaN  ...      NaN      NaN           NaN
# 2     British       Violin    NaN  ...      NaN      NaN           NaN
# 3     British        Cello    NaN  ...      NaN      NaN           NaN
# 4     British  Double Bass    NaN  ...      NaN      NaN           NaN
#
#   Body No. Ticket No. Cabin No. Traveling Companions and other notes Value  \
# 0      NaN        NaN       NaN                                  NaN     1
# 1      NaN        NaN       NaN                                  NaN     1
# 2      NaN        NaN       NaN                                  NaN     1
# 3      NaN        NaN       NaN                                  NaN     1
# 4      NaN        NaN       NaN                                  NaN     1
#
#   Adult/Minor   Sex
# 0       Adult  Male
# 1       Adult  Male
# 2       Adult  Male
# 3       Adult  Male
# 4       Adult  Male
#
# [5 rows x 23 columns]

# %%
# Summarize It (mean, median, mode, variance, std, range)
titanic.body.describe()
# Out:
# count    121.000000
# mean     160.809917
# std       97.696922
# min        1.000000
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max      328.000000
# Name: body, dtype: float64

# %%
titanic.groupby(['survived']).size()
# Out:
# survived
# 0    809
# 1    500
# dtype: int64

# %%
lusitania.describe()
# Out:
#              Value
# count  1961.000000
# mean      0.999490
# std       0.022582
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
titanic['survived'].mean()
# Out:
# 0.3819709702062643

# %%
titanic.age.dtype
# Out:
# dtype('float64')

# %%
# Clean It
titanic_avg_age = titanic.age.mean(axis=0 , skipna=True)
titanic_avg_age
# Out:
# 29.881137667304014

# %%
titanic.age.fillna(titanic_avg_age, inplace=True)

# %%
(cast['title'] == 'Star Wars') & (cast['n'].notnull())].sort_values(by='n')

# %%
female_age = titanic[titanic.sex == 'female']
male_age = titanic[titanic.sex == 'male']

# %%
avg_female_age = female_age.age.mean()
avg_male_age = male_age.age.mean()

# %%
print avg_female_age
print avg_male_age
# Out:
# 28.8869500817
# 30.4307122995

# %%
titanic.groupby([])

# %%
titanic.groupby(['pclass', 'fare']).mean()
# Out:
#                 survived        age     sibsp     parch        body
# pclass fare
# 1      0.0000   0.142857  36.520488  0.000000  0.000000  110.000000
#        5.0000   0.000000  33.000000  0.000000  0.000000         NaN
#        25.5875  0.000000  47.000000  0.000000  0.000000         NaN
#        25.7000  1.000000  55.000000  2.000000  0.000000         NaN
#        25.7417  1.000000  29.881138  0.000000  0.000000         NaN
#        25.9250  0.000000  29.881138  0.000000  0.000000         NaN
#        25.9292  1.000000  48.500000  0.000000  0.000000         NaN
#        26.0000  0.125000  40.470284  0.000000  0.000000  163.666667
#        26.2833  1.000000  19.000000  0.000000  2.000000         NaN
#        26.2875  1.000000  37.666667  0.000000  0.000000         NaN
#        26.3875  1.000000  36.000000  0.000000  0.000000         NaN
#        26.5500  0.454545  44.114752  0.045455  0.045455  179.000000
#        27.4458  1.000000  53.000000  0.000000  0.000000         NaN
#        27.7208  0.555556  37.015935  0.111111  0.000000  189.000000
#        27.7500  0.000000  30.000000  0.000000  0.000000         NaN
#        28.5000  0.500000  49.250000  0.000000  0.000000  166.000000
#        28.5375  1.000000  31.000000  0.000000  0.000000         NaN
#        28.7125  0.000000  50.000000  0.000000  0.000000         NaN
#        29.7000  0.400000  41.776228  0.000000  0.200000  195.500000
#        30.0000  0.800000  36.776228  0.000000  0.000000  126.000000
#        30.5000  0.666667  39.480190  0.000000  0.000000         NaN
#        30.6958  0.000000  42.940569  0.000000  0.000000         NaN
#        31.0000  0.666667  33.293713  0.000000  0.000000         NaN
#        31.6792  0.000000  36.000000  0.000000  0.000000         NaN
#        31.6833  1.000000  29.881138  0.000000  0.000000         NaN
#        32.3208  0.000000  61.000000  0.000000  0.000000   46.000000
#        33.5000  0.000000  61.000000  0.000000  0.000000  245.000000
#        34.0208  0.000000  47.000000  0.000000  0.000000         NaN
#        34.6542  0.000000  71.000000  0.000000  0.000000         NaN
#        35.0000  0.000000  29.881138  0.000000  0.000000         NaN
# ...                  ...        ...       ...       ...         ...
# 3      16.1000  0.250000  27.418713  0.666667  0.166667   33.500000
#        16.7000  1.000000   9.666667  0.666667  1.333333         NaN
#        17.4000  1.000000  36.250000  1.000000  0.000000         NaN
#        17.8000  0.000000  21.500000  1.000000  0.000000         NaN
#        18.0000  0.000000  24.000000  2.000000  0.000000         NaN
#        18.7875  0.500000  18.500000  0.000000  0.000000         NaN
#        19.2583  1.000000   7.625000  1.500000  1.500000         NaN
#        19.9667  0.000000  29.881138  1.000000  0.000000         NaN
#        20.2125  0.000000  20.333333  0.666667  1.333333         NaN
#        20.2500  0.333333  21.333333  0.666667  1.333333  190.000000
#        20.5250  0.666667  24.333333  0.666667  1.333333         NaN
#        20.5750  0.750000  15.042500  1.000000  2.000000         NaN
#        21.0750  0.000000   9.600000  2.400000  1.600000  105.000000
#        21.6792  0.000000  29.881138  2.000000  0.000000         NaN
#        22.0250  1.000000  19.666667  1.333333  1.333333         NaN
#        22.3583  1.000000  29.881138  0.666667  1.333333         NaN
#        22.5250  0.000000  29.333333  0.000000  0.000000  216.500000
#        23.2500  1.000000  29.881138  2.000000  0.000000         NaN
#        23.4500  0.000000  29.881138  1.000000  2.000000         NaN
#        24.1500  0.111111  27.738157  0.888889  0.444444         NaN
#        25.4667  0.000000  29.881138  2.400000  1.600000         NaN
#        27.9000  0.000000  18.333333  2.333333  2.666667         NaN
#        29.1250  0.000000  11.666667  3.333333  1.666667  327.000000
#        31.2750  0.000000  15.714286  3.142857  2.857143         NaN
#        31.3875  0.428571  16.142857  3.142857  2.857143  142.000000
#        34.3750  0.000000  22.400000  1.600000  2.400000         NaN
#        39.6875  0.000000  14.714286  2.857143  1.428571         NaN
#        46.9000  0.000000  18.000000  4.000000  3.000000         NaN
#        56.4958  0.750000  29.690569  0.000000  0.000000         NaN
#        69.5500  0.000000  28.482852  6.727273  3.272727   67.000000
#
# [288 rows x 5 columns]

# %%
sns.boxplot(male_age.age)

# %%
sns.boxplot(female_age.age)

# %%
# Does cleaning it change the summary information?
