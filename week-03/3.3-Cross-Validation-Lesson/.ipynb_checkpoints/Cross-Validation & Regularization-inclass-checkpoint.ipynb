# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Regularization and Cross-Validation
# Week 3 | Lesson 2.4
#
# ### LEARNING OBJECTIVES
# *After this lesson, you will be able to:*
# - Explain the connection between the bias-variance tradeoff and the train-test split
# - Perform a split of data into testing and training sets
# - Make a prediction on the ISE value using a Linear Regression

# %% [markdown]
# ![](assets/the_sweet_spot.png)

# %%
from os import chdir 
chdir('../../../lib/')

# %%
import matplotlib.pyplot as plt
import mglearn
import numpy as np
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
X, y = mglearn.datasets.make_wave(n_samples=60)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
lr = LinearRegression().fit(X_train, y_train)
xfit = np.linspace(-3,3,100)
plt.scatter(X, y)
plt.plot(xfit, xfit*lr.coef_ + lr.intercept_)
print("lr.coef_: {}".format(lr.coef_))
print("lr.intercept_: {}".format(lr.intercept_))
print("training set score: {:.2f}".format(lr.score(X_train, y_train)))
print("test set score: {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# lr.coef_: [ 0.39390555]
# lr.intercept_: -0.0318043430268
# training set score: 0.67
# test set score: 0.66

# %% [markdown]
# ### Linear Regression on the Boston Data

# %%
X, y = mglearn.datasets.load_extended_boston()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
lr = LinearRegression().fit(X_train, y_train)
print("training set score: {:.2f}".format(lr.score(X_train, y_train)))
print("test set score: {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# training set score: 0.95
# test set score: 0.61

# %% [markdown]
# ## Ridge Regression

# %% [markdown]
# Mathematically, Ridge penalizes the L2 norm of the coefficients, or the Euclidean length of w.

# %% [markdown]
# From lecture 2.4:
#
# > The length of the vector, $\mathbf v$ is defined as
#
# > $$||\mathbf v||= \sqrt{\mathbf v \cdot \mathbf v}$$
#
# The length of a vector **IS** the L2 norm.
#
# $$ \texttt{norm}_2 = \sqrt{\mathbf v \cdot \mathbf v} = \sqrt{v_1^2+v_2^2+\dots+v_n^2}$$

# %%
vector_length = lambda x: np.sqrt(np.dot(x, x))
from numpy.linalg import norm

# %%
vector_length((3,4))
# Out:
# 5.0

# %%
norm((3,4))
# Out:
# 5.0

# %%
from sklearn.linear_model import Ridge
ridge = Ridge().fit(X_train, y_train)
print("training set score: {:.2f}".format(ridge.score(X_train, y_train)))
print("test set score: {:.2f}".format(ridge.score(X_test, y_test)))
# Out:
# training set score: 0.89
# test set score: 0.75

# %%
ridge10 = Ridge(alpha=10).fit(X_train, y_train)
print("training set score: {:.2f}".format(ridge10.score(X_train, y_train)))
print("test set score: {:.2f}".format(ridge10.score(X_test, y_test)))
# Out:
# training set score: 0.79
# test set score: 0.64

# %%
ridge01 = Ridge(alpha=0.1).fit(X_train, y_train)
print("training set score: {:.2f}".format(ridge01.score(X_train, y_train)))
print("test set score: {:.2f}".format(ridge01.score(X_test, y_test)))
# Out:
# training set score: 0.93
# test set score: 0.77

# %%
X.shape
# Out:
# (506, 104)

# %%
plt.title("ridge_coefficients")
plt.plot(ridge.coef_, 's', label="Ridge alpha=1")
plt.plot(ridge10.coef_, '^', label="Ridge alpha=10")
plt.plot(ridge01.coef_, 'v', label="Ridge alpha=0.1")
plt.plot(lr.coef_, 'o', label="LinearRegression")
plt.xlabel('Coefficient Index')
plt.ylabel('Coefficient Magnitude')
plt.ylim(-25, 25)
plt.legend()

# %%
mglearn.plots.plot_ridge_n_samples()

# %% [markdown]
# - Without enough data standard regression is useless
# - As more data becomes available, both models improve and standard regression eventually catches up to ridge regression
# - Ridge regression has a decreased *training* performance -- it is harder for the model to "memorize the data"

# %% [markdown]
# ## The Lasso

# %% [markdown]
# Mathematically, the Lasso penalizes the L1 norm of the coefficients, or sum of the absolute values of the coefficients.
#
# $$ \texttt{norm}_1 = \rvert v_1 \rvert+ \rvert v_2 \rvert+\dots+ \rvert v_n \rvert = \sum \rvert v_i \rvert$$
#
# Because of this many coefficients are exactly zero. This is equivalent to saying that these features are not used.

# %%
from sklearn.linear_model import Lasso

# %%
lasso = Lasso().fit(X_train, y_train)
print("training set score: {:.2f}".format(lasso.score(X_train, y_train)))
print("test set score: {:.2f}".format(lasso.score(X_test, y_test)))
print("Number of features used: {}".format(np.sum(lasso.coef_ != 0)))
# Out:
# training set score: 0.29
# test set score: 0.21
# Number of features used: 4

# %%
lasso01 = Lasso(alpha=0.01, max_iter=100000).fit(X_train, y_train)
print("training set score: {:.2f}".format(lasso01.score(X_train, y_train)))
print("test set score: {:.2f}".format(lasso01.score(X_test, y_test)))
print("Number of features used: {}".format(np.sum(lasso01.coef_ != 0)))
# Out:
# training set score: 0.90
# test set score: 0.77
# Number of features used: 33

# %%
lasso0001 = Lasso(alpha=0.0001, max_iter=100000).fit(X_train, y_train)
print("training set score: {:.2f}".format(lasso0001.score(X_train, y_train)))
print("test set score: {:.2f}".format(lasso0001.score(X_test, y_test)))
print("Number of features used: {}".format(np.sum(lasso0001.coef_ != 0)))
# Out:
# training set score: 0.95
# test set score: 0.64
# Number of features used: 94

# %%
lasso.coef_[lasso.coef_ != 0]
# Out:
# array([-5.3529079 , -1.05063037, -3.3104274 , -0.41386744])

# %%
plt.title("ridge_coefficients")
plt.plot(lasso.coef_, 's', label="Lasso alpha=1")
plt.plot(lasso01.coef_, '^', label="Lasso alpha=0.01")
plt.plot(lasso0001.coef_, 'v', label="Lasso alpha=0.0001")

plt.xlabel('Coefficient Index')
plt.ylabel('Coefficient Magnitude')
plt.ylim(-25, 25)
plt.legend()

# %% [markdown]
# ---

# %% [markdown]
# # Cross-Validation

# %%
mglearn.plots.plot_cross_validation()

# %% [markdown]
# In $\mathbf K$-**Fold Cross-Validation** rather than splitting the data into a training set and a test set, the data is split $K$ times and $K$ models are developed.

# %% [markdown]
# We measure then accuracy of each model.

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.metrics import make_scorer, mean_squared_error
MSE = make_scorer(mean_squared_error, greater_is_better=False)

# %%
X, y = mglearn.datasets.load_extended_boston()

# %%
cross_val_scores = cross_val_score(Lasso(), X, y, scoring=MSE, cv=504)
cross_val_scores
# Out:
# array([  1.88751846e+00,   9.11128288e+01,   1.44051136e+02,
#          2.00929506e+01,   4.85722343e-02,   2.86445349e+01,
#          1.16439030e+01,   1.10654964e+01,   4.40054653e+01,
#          1.62378902e+01,   8.45471587e-01,   9.59201335e+00,
#          2.23603790e+01,   1.30587331e+01,   1.06880808e+00,
#          2.15145558e+01,   8.57150799e+00,   2.18562219e+01,
#          5.29456138e+01,   6.76503969e+00,   3.75485607e+01,
#          4.29691800e+01,   3.78081803e+01,   6.23972116e+01,
#          2.96496898e+01,   4.65377140e+01,   1.56877561e+01,
#          2.39185735e+00,   6.30034418e+01,   6.13735061e+01,
#          4.40187554e+01,   6.88386823e+01,   5.64248880e+01,
#          1.93882390e+01,   9.21710640e+00,   7.19852502e+00,
#          1.39994371e+00,   3.76569801e+01,   9.60917559e+01,
#          3.52051302e+00,   5.92187856e-01,   2.15837701e-01,
#          5.93887494e+00,   1.82036520e+01,   8.12385647e+00,
#          2.56716391e+01,   2.60286442e+01,   8.29775082e+00,
#          1.05265979e+01,   9.48431091e+00,   2.03603296e-01,
#          3.33410694e-01,   1.26131182e+01,   1.18043746e+02,
#          1.04213571e-01,   4.73489360e+01,   5.64093798e-01,
#          1.49420442e+01,   1.50471641e+01,   3.75999054e+01,
#          2.35421093e+00,   2.45034699e+00,   8.66679458e+01,
#          1.44223797e+00,   1.79755387e+01,   3.97796198e+00,
#          3.10743117e+01,   8.27623610e+00,   2.40358040e-02,
#          3.98559653e+00,   3.14985150e+00,   6.61127553e-01,
#          5.68922080e-02,   5.05366092e+00,   8.24066430e+00,
#          6.75865850e+00,   3.09229526e+00,   1.14786439e+01,
#          1.30795377e+01,   2.34920213e-02,   4.28456792e-01,
#          9.78970732e-01,   1.39038525e-01,   6.64448526e+00,
#          2.11241343e-01,   2.19850199e+00,   2.28283464e-01,
#          2.05132334e+01,   1.01172672e+00,   2.78576538e+00,
#          7.49235522e-01,   5.02707941e-01,   6.55498333e+00,
#          1.91684769e+01,   2.90979430e+00,   2.08524702e+02,
#          3.66966654e+02,   8.36858662e+01,   2.00284675e+01,
#          9.27890875e+00,   1.79842655e+01,   8.94020094e+00,
#          5.58034344e+00,   4.56202545e+00,   3.16307400e+00,
#          3.16691033e+00,   6.81208866e+00,   6.05732942e+00,
#          9.75453236e-01,   1.68559878e-01,   1.05246191e+01,
#          1.00384008e+01,   2.16665930e+01,   1.48880267e+01,
#          2.99390211e+00,   1.59210786e+01,   3.68821250e+00,
#          1.09861061e+02,   2.14100946e+02,   5.78726475e+01,
#          4.20729399e+01,   2.96134594e+00,   5.57645890e+01,
#          4.83546428e+01,   7.01961664e+00,   2.34763611e-01,
#          1.41837200e+01,   1.04612608e+02,   1.28862612e+02,
#          1.37091924e+02,   7.47410488e+01,   1.26041578e+02,
#          1.32072957e+02,   1.84959222e+01,   4.54081368e+01,
#          2.04190229e-01,   3.90860115e+01,   8.52298460e+01,
#          1.23160872e+02,   1.24069687e+02,   1.09093999e+02,
#          8.21964574e+01,   9.87937279e+01,   3.79779593e+01,
#          3.73220446e+01,   3.25438676e+01,   4.36896985e+01,
#          8.76574541e+01,   3.79401228e+01,   1.20022857e+02,
#          1.05766598e+02,   8.88713953e+01,   4.68164948e+01,
#          8.67814750e+01,   9.54508388e+00,   5.25989914e+00,
#          2.40092715e+01,   7.51587099e+01,   5.84317795e+01,
#          3.17365265e+01,   6.72662972e+01,   4.03928519e+01,
#          5.25602822e+01,   5.25007470e+01,   2.83607796e+01,
#          2.08281141e+01,   8.27921315e+00,   3.00875945e+01,
#          4.18797968e+01,   5.93930280e+01,   5.41243948e+01,
#          3.65267666e+01,   1.38979964e+00,   1.96780608e+01,
#          1.20355982e+01,   3.34165459e+00,   3.03727385e+00,
#          5.02190118e-02,   3.03718553e+00,   2.99961679e+00,
#          5.91166378e-01,   2.51241676e+00,   1.79163840e+00,
#          9.80517462e-01,   3.46326394e+00,   3.59057685e+00,
#          6.39434090e+01,   4.47119480e+01,   3.70008433e+01,
#          1.35548598e+01,   5.25688741e+01,   3.46761329e+01,
#          6.33140659e-04,   8.62295456e-01,   1.40311140e+00,
#          5.71353227e+00,   3.40300069e-01,   1.54591143e+00,
#          1.09650200e+00,   4.32329800e+00,   2.19128767e+00,
#          3.99985509e+01,   1.83095175e+02,   1.31064893e+02,
#          6.22996649e+01,   5.41385833e+00,   1.35805829e+00,
#          3.01877788e+00,   9.16008686e-01,   2.09843741e+00,
#          1.72793059e+01,   2.26923430e+00,   2.26025974e+01,
#          3.07879298e+01,   5.86214376e-01,   6.83149855e+00,
#          5.81946836e-02,   2.42371041e+00,   1.34826823e+02])

# %%
cross_val_scores = cross_val_score(Lasso(), X, y, scoring=MSE)
cross_val_scores
# Out:
# array([  48.47879498,  138.11478786,  115.39576661])

# %%
alphas = [1E-5, 1E-4, 1E-3, 0.01, 0.1, 1, 10, 100, 1000]

for alp in alphas:
    RIDGE_REGRESSOR = Ridge(alpha=alp, max_iter=1E5, normalize=True)
    cross_val_scores = cross_val_score(RIDGE_REGRESSOR, X, y, scoring=MSE)
    mean_mse = np.mean(cross_val_scores)
    print("Mean MSE for alpha={:6} is {:.2f}".format(alp, mean_mse))
                                             
mn_mn_sq_ers = [np.mean(cross_val_score(Ridge(alpha=alp), X, y, scoring=MSE)) 
                for alp in alphas]
plt.plot(mn_mn_sq_ers)
plt.ylim(-5, 1000)
# Out:
# Mean MSE for alpha= 1e-05 is 772195.32
# Mean MSE for alpha=0.0001 is 529763.69
# Mean MSE for alpha= 0.001 is 89642.77
# Mean MSE for alpha=  0.01 is 3213.63
# Mean MSE for alpha=   0.1 is 4095.72
# Mean MSE for alpha=     1 is 240.00
# Mean MSE for alpha=    10 is 169.93
# Mean MSE for alpha=   100 is 89.20
# Mean MSE for alpha=  1000 is 102.61
# (-5, 1000)

# %%
alphas = [1E-5, 1E-4, 1E-3, 0.01, 0.1, 1, 10, 100, 1000]

for alp in alphas:
    LASSO_REGRESSOR = Lasso(alpha=alp, max_iter=1E5, normalize=True)
    cross_val_scores = cross_val_score(LASSO_REGRESSOR, X, y, scoring=MSE)
    mean_mse = np.mean(cross_val_scores)
    print("Mean MSE for alpha={:6} is {:.2f}".format(alp, mean_mse))
                                             
mn_mn_sq_ers = [np.mean(cross_val_score(Lasso(alpha=alp, max_iter=1E5, normalize=True), X, y, scoring=MSE)) for alp in alphas]
plt.plot(mn_mn_sq_ers)
plt.ylim(-5, 1000)
# Out:
# Mean MSE for alpha= 1e-05 is 701456.35
# Mean MSE for alpha=0.0001 is 196364.98
# Mean MSE for alpha= 0.001 is 202.54
# Mean MSE for alpha=  0.01 is 32.42
# Mean MSE for alpha=   0.1 is 50.53
# Mean MSE for alpha=     1 is 111.15
# Mean MSE for alpha=    10 is 111.15
# Mean MSE for alpha=   100 is 111.15
# Mean MSE for alpha=  1000 is 111.15
# (-5, 1000)

# %% [markdown]
# ## The ElasticNet
#
# The best of both worlds.

# %% [markdown]
# http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html

# %% [markdown]
# Linear regression with combined L1 and L2 priors as regularizer.
#
# Minimizes the objective function, for an $\alpha$ as a learning rate and $\gamma$ as an `l1 ratio`:
#
#
# $$\frac{1}{2n}\cdot\texttt{norm}_2(y - Xw)+\alpha\gamma\cdot\texttt{norm}_1(w)+\alpha(1-\gamma)\cdot\texttt{norm}_2(w)$$

# %%
from sklearn.linear_model import ElasticNet

# %%
elastic_net = ElasticNet().fit(X_train, y_train)
print("training set score: {:.2f}".format(elastic_net.score(X_train, y_train)))
print("test set score: {:.2f}".format(elastic_net.score(X_test, y_test)))
print("Number of features used: {}".format(np.sum(elastic_net.coef_ != 0)))
# Out:
# training set score: 0.33
# test set score: 0.22
# Number of features used: 38

# %%
elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.2).fit(X_train, y_train)
print("training set score: {:.2f}".format(elastic_net.score(X_train, y_train)))
print("test set score: {:.2f}".format(elastic_net.score(X_test, y_test)))
print("Number of features used: {}".format(np.sum(elastic_net.coef_ != 0)))
# Out:
# training set score: 0.71
# test set score: 0.53
# Number of features used: 77

# %% [markdown]
# ### NOW WE HAVE TWO PARAMETERS TO TUNE!!!

# %% [markdown]
# ## Grid Search
#
# An exhaustive search over specified parameter values for an estimator.

# %%
from sklearn.model_selection import GridSearchCV

# %%
elastic_net = ElasticNet()
parameters = { 'alpha' : [1E-4, 1E-3, 1E-2, 0.1, 1, 10, 100, 1000], 
              'l1_ratio' : np.linspace(0,1,11)}
REGRESSOR = GridSearchCV(elastic_net, parameters, scoring=MSE)
REGRESSOR.fit(X, y)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-66-53cb5ca87932> in <module>()
#       3               'l1_ratio' : np.linspace(0,1,11)}
#       4 REGRESSOR = GridSearchCV(elastic_net, parameters, scoring=MSE)
# ----> 5 REGRESSOR.fit(X, y)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/model_selection/_search.pyc in fit(self, X, y, groups)
#     938             train/test set.
#     939         """
# --> 940         return self._fit(X, y, groups, ParameterGrid(self.param_grid))
#     941
#     942
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/model_selection/_search.pyc in _fit(self, X, y, groups, parameter_iterable)
#     539         self.scorer_ = check_scoring(self.estimator, scoring=self.scoring)
#     540
# --> 541         X, y, groups = indexable(X, y, groups)
#     542         n_splits = cv.get_n_splits(X, y, groups)
#     543         if self.verbose > 0 and isinstance(parameter_iterable, Sized):
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in indexable(*iterables)
#     204         else:
#     205             result.append(np.array(X))
# --> 206     check_consistent_length(*result)
#     207     return result
#     208
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_consistent_length(*arrays)
#     175     """
#     176
# --> 177     lengths = [_num_samples(X) for X in arrays if X is not None]
#     178     uniques = np.unique(lengths)
#     179     if len(uniques) > 1:
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in _num_samples(x)
#     124         if len(x.shape) == 0:
#     125             raise TypeError("Singleton array %r cannot be considered"
# --> 126                             " a valid collection." % x)
#     127         return x.shape[0]
#     128     else:
#
# TypeError: Singleton array 1.0 cannot be considered a valid collection.

# %%
REGRESSOR.best_estimator_
# Out:
# ElasticNet(alpha=0.0001, copy_X=True, fit_intercept=True,
#       l1_ratio=0.90000000000000002, max_iter=1000, normalize=False,
#       positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
import pandas as pd
import seaborn as sns

# %%
grid_search_results = pd.DataFrame(REGRESSOR.cv_results_)

# %%
grid_search_results
# Out:
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 0        0.055706         0.002543       116.895337          6.274532
# 1        0.048977         0.000807       124.951870          6.215525
# 2        0.045694         0.000530       134.391864          6.152931
# 3        0.056613         0.001139       146.500311          6.085898
# 4        0.048257         0.000418       160.617497          6.012978
# 5        0.057579         0.001585       176.801557          5.933093
# 6        0.039616         0.000396       194.302750          5.844803
# 7        0.039932         0.000446       215.931180          5.744627
# 8        0.041921         0.000553       244.798967          5.624939
# 9        0.041790         0.000511       277.540080          5.470618
# 10       0.042774         0.000519       249.093371          5.247857
# 11       0.047415         0.000460        34.946482          8.945566
# 12       0.041826         0.000747        35.425872          8.778535
# 13       0.043847         0.000532        36.147598          8.596565
# 14       0.043276         0.000675        37.255581          8.400436
# 15       0.039405         0.000622        38.624356          8.187641
# 16       0.043274         0.000428        41.179569          7.955195
# 17       0.041407         0.000541        45.811747          7.697795
# 18       0.040918         0.000585        53.111301          7.406448
# 19       0.035170         0.000455        63.243071          7.064727
# 20       0.038380         0.000611        87.351337          6.648886
# 21       0.035221         0.000740       208.878411          5.913520
# 22       0.051830         0.000471        33.303437         14.435129
# 23       0.030856         0.000386        33.043711         14.202502
# 24       0.029988         0.000388        32.801717         13.956775
# 25       0.030345         0.000362        32.501617         13.687667
# 26       0.026973         0.000383        32.172732         13.385202
# 27       0.025698         0.000435        31.800252         13.058495
# 28       0.024655         0.000378        31.364610         12.684557
# 29       0.025709         0.000363        30.759808         12.244364
# ..            ...              ...              ...               ...
# 58       0.000986         0.000291       111.117152         79.085177
# 59       0.000903         0.000254       111.117152         79.085177
# 60       0.000960         0.000273       111.117152         79.085177
# 61       0.000943         0.000275       111.117152         79.085177
# 62       0.001015         0.000280       111.117152         79.085177
# 63       0.000999         0.000286       111.117152         79.085177
# 64       0.000923         0.000257       111.117152         79.085177
# 65       0.001061         0.000280       111.117152         79.085177
# 66       0.043447         0.000380       110.070614         78.037745
# 67       0.000954         0.000262       111.117152         79.085177
# 68       0.001008         0.000274       111.117152         79.085177
# 69       0.000933         0.000263       111.117152         79.085177
# 70       0.000879         0.000258       111.117152         79.085177
# 71       0.000895         0.000333       111.117152         79.085177
# 72       0.001016         0.000354       111.117152         79.085177
# 73       0.000912         0.000255       111.117152         79.085177
# 74       0.000933         0.000256       111.117152         79.085177
# 75       0.000924         0.000261       111.117152         79.085177
# 76       0.000905         0.000261       111.117152         79.085177
# 77       0.044704         0.000455       111.010325         78.977176
# 78       0.000920         0.000270       111.117152         79.085177
# 79       0.001068         0.000480       111.117152         79.085177
# 80       0.001002         0.000286       111.117152         79.085177
# 81       0.000983         0.000264       111.117152         79.085177
# 82       0.002510         0.000350       111.117152         79.085177
# 83       0.001423         0.000463       111.117152         79.085177
# 84       0.001169         0.000298       111.117152         79.085177
# 85       0.001316         0.000471       111.117152         79.085177
# 86       0.001373         0.000399       111.117152         79.085177
# 87       0.000971         0.000385       111.117152         79.085177
#
#    param_alpha param_l1_ratio                                params  \
# 0       0.0001              0  {u'alpha': 0.0001, u'l1_ratio': 0.0}
# 1       0.0001            0.1  {u'alpha': 0.0001, u'l1_ratio': 0.1}
# 2       0.0001            0.2  {u'alpha': 0.0001, u'l1_ratio': 0.2}
# 3       0.0001            0.3  {u'alpha': 0.0001, u'l1_ratio': 0.3}
# 4       0.0001            0.4  {u'alpha': 0.0001, u'l1_ratio': 0.4}
# 5       0.0001            0.5  {u'alpha': 0.0001, u'l1_ratio': 0.5}
# 6       0.0001            0.6  {u'alpha': 0.0001, u'l1_ratio': 0.6}
# 7       0.0001            0.7  {u'alpha': 0.0001, u'l1_ratio': 0.7}
# 8       0.0001            0.8  {u'alpha': 0.0001, u'l1_ratio': 0.8}
# 9       0.0001            0.9  {u'alpha': 0.0001, u'l1_ratio': 0.9}
# 10      0.0001              1  {u'alpha': 0.0001, u'l1_ratio': 1.0}
# 11       0.001              0   {u'alpha': 0.001, u'l1_ratio': 0.0}
# 12       0.001            0.1   {u'alpha': 0.001, u'l1_ratio': 0.1}
# 13       0.001            0.2   {u'alpha': 0.001, u'l1_ratio': 0.2}
# 14       0.001            0.3   {u'alpha': 0.001, u'l1_ratio': 0.3}
# 15       0.001            0.4   {u'alpha': 0.001, u'l1_ratio': 0.4}
# 16       0.001            0.5   {u'alpha': 0.001, u'l1_ratio': 0.5}
# 17       0.001            0.6   {u'alpha': 0.001, u'l1_ratio': 0.6}
# 18       0.001            0.7   {u'alpha': 0.001, u'l1_ratio': 0.7}
# 19       0.001            0.8   {u'alpha': 0.001, u'l1_ratio': 0.8}
# 20       0.001            0.9   {u'alpha': 0.001, u'l1_ratio': 0.9}
# 21       0.001              1   {u'alpha': 0.001, u'l1_ratio': 1.0}
# 22        0.01              0    {u'alpha': 0.01, u'l1_ratio': 0.0}
# 23        0.01            0.1    {u'alpha': 0.01, u'l1_ratio': 0.1}
# 24        0.01            0.2    {u'alpha': 0.01, u'l1_ratio': 0.2}
# 25        0.01            0.3    {u'alpha': 0.01, u'l1_ratio': 0.3}
# 26        0.01            0.4    {u'alpha': 0.01, u'l1_ratio': 0.4}
# 27        0.01            0.5    {u'alpha': 0.01, u'l1_ratio': 0.5}
# 28        0.01            0.6    {u'alpha': 0.01, u'l1_ratio': 0.6}
# 29        0.01            0.7    {u'alpha': 0.01, u'l1_ratio': 0.7}
# ..         ...            ...                                   ...
# 58          10            0.3      {u'alpha': 10, u'l1_ratio': 0.3}
# 59          10            0.4      {u'alpha': 10, u'l1_ratio': 0.4}
# 60          10            0.5      {u'alpha': 10, u'l1_ratio': 0.5}
# 61          10            0.6      {u'alpha': 10, u'l1_ratio': 0.6}
# 62          10            0.7      {u'alpha': 10, u'l1_ratio': 0.7}
# 63          10            0.8      {u'alpha': 10, u'l1_ratio': 0.8}
# 64          10            0.9      {u'alpha': 10, u'l1_ratio': 0.9}
# 65          10              1      {u'alpha': 10, u'l1_ratio': 1.0}
# 66         100              0     {u'alpha': 100, u'l1_ratio': 0.0}
# 67         100            0.1     {u'alpha': 100, u'l1_ratio': 0.1}
# 68         100            0.2     {u'alpha': 100, u'l1_ratio': 0.2}
# 69         100            0.3     {u'alpha': 100, u'l1_ratio': 0.3}
# 70         100            0.4     {u'alpha': 100, u'l1_ratio': 0.4}
# 71         100            0.5     {u'alpha': 100, u'l1_ratio': 0.5}
# 72         100            0.6     {u'alpha': 100, u'l1_ratio': 0.6}
# 73         100            0.7     {u'alpha': 100, u'l1_ratio': 0.7}
# 74         100            0.8     {u'alpha': 100, u'l1_ratio': 0.8}
# 75         100            0.9     {u'alpha': 100, u'l1_ratio': 0.9}
# 76         100              1     {u'alpha': 100, u'l1_ratio': 1.0}
# 77        1000              0    {u'alpha': 1000, u'l1_ratio': 0.0}
# 78        1000            0.1    {u'alpha': 1000, u'l1_ratio': 0.1}
# 79        1000            0.2    {u'alpha': 1000, u'l1_ratio': 0.2}
# 80        1000            0.3    {u'alpha': 1000, u'l1_ratio': 0.3}
# 81        1000            0.4    {u'alpha': 1000, u'l1_ratio': 0.4}
# 82        1000            0.5    {u'alpha': 1000, u'l1_ratio': 0.5}
# 83        1000            0.6    {u'alpha': 1000, u'l1_ratio': 0.6}
# 84        1000            0.7    {u'alpha': 1000, u'l1_ratio': 0.7}
# 85        1000            0.8    {u'alpha': 1000, u'l1_ratio': 0.8}
# 86        1000            0.9    {u'alpha': 1000, u'l1_ratio': 0.9}
# 87        1000              1    {u'alpha': 1000, u'l1_ratio': 1.0}
#
#     rank_test_score  split0_test_score  split0_train_score  split1_test_score  \
# 0                12          28.974030            7.371388          20.082764
# 1                11          29.951568            7.286328          20.680175
# 2                10          31.267694            7.196733          21.346691
# 3                 9          33.039183            7.102079          22.080419
# 4                 8          35.420503            7.000487          22.854972
# 5                 7          38.457437            6.891328          23.603740
# 6                 6          42.262270            6.773734          24.638751
# 7                 4          47.101450            6.647762          25.955297
# 8                 3          53.006972            6.506960          27.104383
# 9                 1          59.627591            6.341959          28.418476
# 10                2          61.424626            6.140796          28.268658
# 11               77          14.421852           10.808444          16.341538
# 12               76          14.511871           10.593139          15.993815
# 13               75          14.702791           10.362369          15.591929
# 58        0.000046       44.029614        16.367412
# 59        0.000005       44.029614        16.367412
# 60        0.000016       44.029614        16.367412
# 61        0.000013       44.029614        16.367412
# 62        0.000008       44.029614        16.367412
# 63        0.000016       44.029614        16.367412
# 64        0.000008       44.029614        16.367412
# 65        0.000017       44.029614        16.367412
# 66        0.000020       43.453510        15.655719
# 67        0.000009       44.029614        16.367412
# 68        0.000005       44.029614        16.367412
# 69        0.000006       44.029614        16.367412
# 70        0.000001       44.029614        16.367412
# 71        0.000103       44.029614        16.367412
# 72        0.000048       44.029614        16.367412
# 73        0.000005       44.029614        16.367412
# 74        0.000005       44.029614        16.367412
# 75        0.000005       44.029614        16.367412
# 76        0.000008       44.029614        16.367412
# 77        0.000074       43.971184        16.292992
# 78        0.000012       44.029614        16.367412
# 79        0.000256       44.029614        16.367412
# 80        0.000031       44.029614        16.367412
# 81        0.000007       44.029614        16.367412
# 82        0.000111       44.029614        16.367412
# 83        0.000104       44.029614        16.367412
# 84        0.000022       44.029614        16.367412
# 85        0.000165       44.029614        16.367412
# 86        0.000085       44.029614        16.367412
# 87        0.000117       44.029614        16.367412
#
# [88 rows x 18 columns]

# %%
grid_search_results.head(1)
# Out:
#    mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 0       0.055706         0.002543       116.895337          6.274532
#
#   param_alpha param_l1_ratio                                params  \
# 0      0.0001              0  {u'alpha': 0.0001, u'l1_ratio': 0.0}
#
#    rank_test_score  split0_test_score  split0_train_score  split1_test_score  \
# 0               12           28.97403            7.371388          20.082764
#
#    split1_train_score  split2_test_score  split2_train_score  std_fit_time  \
# 0            7.499936         302.728823            3.952273      0.018311
#
#    std_score_time  std_test_score  std_train_score
# 0        0.003018      131.065145         1.642924

# %%
grid_search_results['alpha'] = grid_search_results['params'].apply(lambda x: x['alpha'])
grid_search_results['l1_ratio'] = grid_search_results['params'].apply(lambda x: x['l1_ratio'])

# %%
grid_search_results.head(1)
# Out:
#    mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 0       0.055706         0.002543       116.895337          6.274532
#
#   param_alpha param_l1_ratio                                params  \
# 0      0.0001              0  {u'alpha': 0.0001, u'l1_ratio': 0.0}
#
#    rank_test_score  split0_test_score  split0_train_score  split1_test_score  \
# 0               12           28.97403            7.371388          20.082764
#
#    split1_train_score  split2_test_score  split2_train_score  std_fit_time  \
# 0            7.499936         302.728823            3.952273      0.018311
#
#    std_score_time  std_test_score  std_train_score   alpha  l1_ratio
# 0        0.003018      131.065145         1.642924  0.0001       0.0

# %%
grid_search_results_of_interest = grid_search_results[['mean_test_score', 'mean_train_score', 'alpha', 'l1_ratio']]

# %%
grid_search_results_of_interest.head()
# Out:
#    mean_test_score  mean_train_score   alpha  l1_ratio
# 0       116.895337          6.274532  0.0001       0.0
# 1       124.951870          6.215525  0.0001       0.1
# 2       134.391864          6.152931  0.0001       0.2
# 3       146.500311          6.085898  0.0001       0.3
# 4       160.617497          6.012978  0.0001       0.4

# %%
def get_mean_test_score(x,y):
    index = grid_search_results[(grid_search_results['alpha']==x) & (grid_search_results['l1_ratio'] == y)].index[0]
    return grid_search_results.get_value(index, 'mean_test_score')

# %%
xs = grid_search_results['alpha'].unique()
ys = grid_search_results['l1_ratio'].unique()

intensity = [[get_mean_test_score(x, y) for x in xs] for y in ys]

plt.xscale('log')
plt.pcolormesh(xs, ys, intensity, cmap='RdBu_r')
plt.colorbar() #need a colorbar to show the intensity scale
